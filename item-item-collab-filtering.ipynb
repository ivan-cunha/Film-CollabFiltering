# %% [markdown]
# # Setup

# %% [markdown]
# The setup is mostly the same of user-user, so for explanation of what is being done is in the other file, the differences will be explained.

# %%
import pandas as pd
import numpy as np

# %%
def crop(df, percent):
    print("Users:", len(df["userId"].unique()))
    print("Movies:", len(df["movieId"].unique()))
    user_counts = df["userId"].value_counts()
    top_users = user_counts[user_counts > user_counts.quantile(percent)]
    df = df[df["userId"].isin(top_users.index)]
    movie_counts = df["movieId"].value_counts()
    top_movies = movie_counts[movie_counts > movie_counts.quantile(percent)]
    df = df[df["movieId"].isin(top_movies.index)]
    print(df.shape)
    print("Users:", len(df["userId"].unique()))
    print("Movies:", len(df["movieId"].unique()))
    return df

# %%
df = pd.read_csv("./rating.csv", sep=",")
df = crop(df, 0.97)
df.drop(columns=["timestamp"], inplace=True)
# Out:
# Users: 138493
# Movies: 26744
# (1761018, 4)
# Users: 4144
# Movies: 770

# %%
matrix = df.pivot(index="userId", columns="movieId", values="rating")
matrix.head()
# Out:
# movieId  1      2      6      10     11     16     17     19     21     22     \
# userId
# 54         4.0    3.0    3.0    4.0    5.0    2.0    2.0    NaN    2.0    3.0
# 104        NaN    NaN    NaN    NaN    NaN    NaN    3.0    NaN    3.0    NaN
# 116        3.0    2.0    1.5    2.0    2.0    3.5    NaN    2.5    3.5    2.0
# 156        5.0    5.0    4.0    4.0    5.0    4.0    4.0    NaN    4.0    4.0
# 208        4.0    NaN    NaN    NaN    3.0    1.5    5.0    NaN    4.5    NaN
#
# movieId  ...  50872  51255  51662  54286  55820  56367  58559  59315  60069  \
# userId   ...
# 54       ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 104      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 116      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 156      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 208      ...    4.0    NaN    3.0    4.5    4.0    4.5    3.5    NaN    3.5
#
# movieId  79132
# userId
# 54         NaN
# 104        NaN
# 116        NaN
# 156        NaN
# 208        NaN
#
# [5 rows x 770 columns]

# %% [markdown]
# Instead of getting the deviation for the users, we will get the deviation for the movies

# %%
movie_mean = matrix.apply(lambda column: column.mean(), axis=0)
movie_mean.head()
# Out:
# movieId
# 1     3.874794
# 2     2.918415
# 6     3.781544
# 10    3.258226
# 11    3.407371
# dtype: float64

# %%
matrix = matrix.apply(lambda row: row - row.mean(), axis=1)
matrix.head()
# Out:
# movieId     1         2         6         10        11        16        17     \
# userId
# 54       0.289617 -0.710383 -0.710383  0.289617  1.289617 -1.710383 -1.710383
# 104           NaN       NaN       NaN       NaN       NaN       NaN  0.027132
# 116      0.437630 -0.562370 -1.062370 -0.562370 -0.562370  0.937630       NaN
# 156      0.913861  0.913861 -0.086139 -0.086139  0.913861 -0.086139 -0.086139
# 208      0.381643       NaN       NaN       NaN -0.618357 -2.118357  1.381643
#
# movieId    19        21        22     ...     50872  51255     51662  \
# userId                                ...
# 54           NaN -1.710383 -0.710383  ...       NaN    NaN       NaN
# 104          NaN  0.027132       NaN  ...       NaN    NaN       NaN
# 116     -0.06237  0.937630 -0.562370  ...       NaN    NaN       NaN
# 156          NaN -0.086139 -0.086139  ...       NaN    NaN       NaN
# 208          NaN  0.881643       NaN  ...  0.381643    NaN -0.618357
#
# movieId     54286     55820     56367     58559  59315     60069  79132
# userId
# 54            NaN       NaN       NaN       NaN    NaN       NaN    NaN
# 104           NaN       NaN       NaN       NaN    NaN       NaN    NaN
# 116           NaN       NaN       NaN       NaN    NaN       NaN    NaN
# 156           NaN       NaN       NaN       NaN    NaN       NaN    NaN
# 208      0.881643  0.381643  0.881643 -0.118357    NaN -0.118357    NaN
#
# [5 rows x 770 columns]

# %% [markdown]
# # Item-Item Collaborative Filtering

# %% [markdown]
# ## Correlation Matrix

# %%
min_common_items = 10
correlation_matrix = matrix.corr(method="pearson", min_periods=min_common_items)

# %%
correlation_matrix.head()
# Out:
# movieId     1         2         6         10        11        16        17     \
# movieId
# 1        1.000000  0.032350 -0.045474  0.007930  0.091920 -0.101956  0.029521
# 2        0.032350  1.000000 -0.077871  0.048924  0.022701 -0.082803 -0.022878
# 6       -0.045474 -0.077871  1.000000  0.070428 -0.009265  0.300902 -0.059671
# 10       0.007930  0.048924  0.070428  1.000000  0.094478  0.020054 -0.048068
# 11       0.091920  0.022701 -0.009265  0.094478  1.000000 -0.113211  0.097418
#
# movieId     19        21        22     ...     50872     51255     51662  \
# movieId                                ...
# 1       -0.118515  0.017264 -0.067205  ...  0.206318  0.048640 -0.127633
# 2        0.118032 -0.053834  0.143411  ... -0.032416 -0.008662  0.031620
# 6       -0.039032  0.045133 -0.048892  ... -0.013473  0.021281 -0.007797
# 10       0.106639 -0.004536  0.110075  ... -0.037923 -0.001136  0.007451
# 11      -0.135341 -0.028771  0.205496  ...  0.040852 -0.086583 -0.058262
#
# movieId     54286     55820     56367     58559     59315     60069     79132
# movieId
# 1        0.027838  0.017583  0.050641  0.035911  0.052996  0.174475 -0.015871
# 2       -0.093059 -0.191137 -0.062120 -0.075859 -0.002581 -0.014914 -0.012359
# 6        0.089102  0.139498 -0.052589  0.094676  0.011640  0.064027  0.121563
# 10       0.059771 -0.092602 -0.134255  0.053913  0.138779 -0.024307 -0.006317
# 11       0.039799 -0.167520 -0.024820 -0.068720 -0.000442 -0.020111 -0.059836
#
# [5 rows x 770 columns]

# %% [markdown]
# ## Recomendation

# %%
def predict_ratings(user_id, top_n=20):
    def weighted_avg_rating(movie):
        movie = movie.iloc[0]
        top_20_corr_movies = correlation_matrix.loc[matrix.loc[user_id].notna()].abs()[movie].nlargest(top_n).index[1:]
        rating = (matrix.loc[user_id, top_20_corr_movies] * correlation_matrix.loc[movie, top_20_corr_movies]).sum() / correlation_matrix.loc[movie, top_20_corr_movies].abs().sum() if correlation_matrix.loc[movie, top_20_corr_movies].abs().sum() != 0 else 0 
        return rating
    unrated_movies = matrix.loc[user_id][matrix.loc[user_id].isna()].index
    predicted_ratings = pd.DataFrame(index=unrated_movies, data=unrated_movies).apply(weighted_avg_rating, axis=1)
    predicted_ratings.columns = ['movie_id', 'predicted_rating']

    return (predicted_ratings).dropna()

# %% [markdown]
# # Tests

# %%
def predict_ratings_test(user_id, top_n=20):
    def weighted_avg_rating(movie):
        movie = movie.iloc[0]
        top_20_corr_movies = correlation_matrix.loc[matrix.loc[user_id].notna()].abs()[movie].nlargest(top_n).index[1:]
        rating = (matrix.loc[user_id, top_20_corr_movies] * correlation_matrix.loc[movie, top_20_corr_movies]).sum() / correlation_matrix.loc[movie, top_20_corr_movies].abs().sum() if correlation_matrix.loc[movie, top_20_corr_movies].abs().sum() != 0 else 0 
        return rating
    unrated_movies = matrix.loc[user_id][matrix.loc[user_id].notna()].index
    predicted_ratings = pd.DataFrame(index=unrated_movies, data=unrated_movies).apply(weighted_avg_rating, axis=1)
    predicted_ratings.columns = ['movie_id', 'predicted_rating']

    return (predicted_ratings).dropna()

# %%
users = matrix.index.tolist()

# %%
y_pred = np.array(list())
y_true = np.array(list())
for user in users:
    deviations = np.array(predict_ratings_test(user))
    ratings = np.array(matrix.loc[user][matrix.loc[user].notna()])
    y_pred = np.append(y_pred, deviations)
    y_true = np.append(y_true, ratings)

# %%
mse = np.mean((y_true - y_pred) ** 2)
mae = np.mean(np.abs(y_true - y_pred))
rmse = np.sqrt(np.mean((y_true - y_pred)**2))

# %%
print("MSE: ", round(mse, 3))
print("MAE: ", round(mae, 3))
print("RMSE: ", round(rmse, 3))
# Out:
# MSE:  0.546
# MAE:  0.563
# RMSE:  0.739

# %%
error = y_true - y_pred
lower, higher = np.percentile(error, [10,90], method="normal_unbiased")

# %%
print(f"Lower bound: {lower}; High bound: {higher}")
# Out:
# Lower bound: -0.9739502797609579; High bound: 0.8232889251775786
