# %% [markdown]
# # Setup

# %% [markdown]
# The setup is mostly the same of user-user, so for explanation of what is being done is in the other file, the differences will be explained.

# %%
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
def crop(df, percent):
    print("Users:", len(df["userId"].unique()))
    print("Movies:", len(df["movieId"].unique()))
    user_counts = df["userId"].value_counts()
    top_users = user_counts[user_counts > user_counts.quantile(percent)]
    df = df[df["userId"].isin(top_users.index)]
    movie_counts = df["movieId"].value_counts()
    top_movies = movie_counts[movie_counts > movie_counts.quantile(percent)]
    df = df[df["movieId"].isin(top_movies.index)]
    print(df.shape)
    print("Users:", len(df["userId"].unique()))
    print("Movies:", len(df["movieId"].unique()))
    return df

# %%
df = pd.read_csv("./rating.csv", sep=",")
df = crop(df, 0.97)
df.drop(columns=["timestamp"], inplace=True)
# Out:
# Users: 138493
# Movies: 26744
# (1761018, 4)
# Users: 4144
# Movies: 770

# %%
matrix = df.pivot(index="userId", columns="movieId", values="rating")
matrix.head()
# Out:
# movieId  1      2      6      10     11     16     17     19     21     22     \
# userId
# 54         4.0    3.0    3.0    4.0    5.0    2.0    2.0    NaN    2.0    3.0
# 104        NaN    NaN    NaN    NaN    NaN    NaN    3.0    NaN    3.0    NaN
# 116        3.0    2.0    1.5    2.0    2.0    3.5    NaN    2.5    3.5    2.0
# 156        5.0    5.0    4.0    4.0    5.0    4.0    4.0    NaN    4.0    4.0
# 208        4.0    NaN    NaN    NaN    3.0    1.5    5.0    NaN    4.5    NaN
#
# movieId  ...  50872  51255  51662  54286  55820  56367  58559  59315  60069  \
# userId   ...
# 54       ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 104      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 116      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 156      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 208      ...    4.0    NaN    3.0    4.5    4.0    4.5    3.5    NaN    3.5
#
# movieId  79132
# userId
# 54         NaN
# 104        NaN
# 116        NaN
# 156        NaN
# 208        NaN
#
# [5 rows x 770 columns]

# %% [markdown]
# Instead of getting the deviation for the users, we will get the deviation for the movies

# %%
movie_mean = matrix.apply(lambda column: column.mean(), axis=0)
movie_mean.head()
# Out:
# movieId
# 1     3.874794
# 2     2.918415
# 6     3.781544
# 10    3.258226
# 11    3.407371
# dtype: float64

# %%
matrix = matrix.apply(lambda column: column - column.mean(), axis=0)
matrix.head()
# Out:
# movieId     1         2         6         10        11        16        17     \
# userId
# 54       0.125206  0.081585 -0.781544  0.741774  1.592629 -1.754585 -1.740595
# 104           NaN       NaN       NaN       NaN       NaN       NaN -0.740595
# 116     -0.874794 -0.918415 -2.281544 -1.258226 -1.407371 -0.254585       NaN
# 156      1.125206  2.081585  0.218456  0.741774  1.592629  0.245415  0.259405
# 208      0.125206       NaN       NaN       NaN -0.407371 -2.254585  1.259405
#
# movieId     19       21        22     ...     50872  51255    51662     54286  \
# userId                                ...
# 54            NaN -1.45417 -0.045602  ...       NaN    NaN      NaN       NaN
# 104           NaN -0.45417       NaN  ...       NaN    NaN      NaN       NaN
# 116      0.112069  0.04583 -1.045602  ...       NaN    NaN      NaN       NaN
# 156           NaN  0.54583  0.954398  ...       NaN    NaN      NaN       NaN
# 208           NaN  1.04583       NaN  ...  0.192187    NaN -0.49674  0.698342
#
# movieId     55820     56367     58559  59315     60069  79132
# userId
# 54            NaN       NaN       NaN    NaN       NaN    NaN
# 104           NaN       NaN       NaN    NaN       NaN    NaN
# 116           NaN       NaN       NaN    NaN       NaN    NaN
# 156           NaN       NaN       NaN    NaN       NaN    NaN
# 208      0.015837  0.687464 -0.641391    NaN -0.498801    NaN
#
# [5 rows x 770 columns]

# %% [markdown]
# # Item-Item Collaborative Filtering

# %% [markdown]
# ## Correlation Matrix

# %%
min_common_items = 10
correlation_matrix = matrix.corr(method="pearson", min_periods=min_common_items)

# %%
correlation_matrix.head()
# Out:
# movieId     1         2         6         10        11        16        17     \
# movieId
# 1        1.000000  0.276539  0.144652  0.252121  0.322261  0.108877  0.242555
# 2        0.276539  1.000000  0.135875  0.304847  0.269987  0.149691  0.185187
# 6        0.144652  0.135875  1.000000  0.258395  0.197951  0.401036  0.136173
# 10       0.252121  0.304847  0.258395  1.000000  0.328231  0.231987  0.193134
# 11       0.322261  0.269987  0.197951  0.328231  1.000000  0.096884  0.283914
#
# movieId     19        21        22     ...     50872     51255     51662  \
# movieId                                ...
# 1        0.094306  0.228550  0.208346  ...  0.354184  0.219426  0.060716
# 2        0.294449  0.168977  0.361049  ...  0.182582  0.194943  0.227374
# 6        0.098752  0.206873  0.157865  ...  0.164174  0.147110  0.155239
# 10       0.281455  0.212749  0.346872  ...  0.177112  0.193046  0.210082
# 11       0.089616  0.179375  0.407207  ...  0.246624  0.141303  0.134532
#
# movieId     54286     55820     56367     58559     59315     60069     79132
# movieId
# 1        0.213517  0.163525  0.230065  0.189269  0.248859  0.303660  0.136066
# 2        0.162258  0.006213  0.171186  0.148527  0.249273  0.158311  0.172640
# 6        0.245282  0.230089  0.127386  0.221842  0.189801  0.178740  0.241999
# 10       0.267276  0.072280  0.113344  0.231345  0.340094  0.141289  0.208618
# 11       0.246151  0.025721  0.204431  0.118324  0.236691  0.158988  0.126388
#
# [5 rows x 770 columns]

# %% [markdown]
# ## Recomendation

# %%
def predict_ratings(user_id, top_n=20):
    unrated_movies = matrix.loc[user_id][matrix.loc[user_id].isna()].index

    def weighted_avg_rating(movie):
        top_20_corr_movies = correlation_matrix.loc[matrix.loc[user_id].notna()].abs()[movie].nlargest(top_n).index[1:]
        rating = matrix.loc[user_id, top_20_corr_movies] * correlation_matrix.loc[movie, top_20_corr_movies] / correlation_matrix.loc[movie, top_20_corr_movies].abs().sum() if correlation_matrix.loc[movie, top_20_corr_movies].abs().sum() != 0 else 0 
        return rating

    # Apply the function to the unrated movies
    predicted_ratings = pd.DataFrame(unrated_movies).apply(weighted_avg_rating)

    # Rename the columns
    predicted_ratings.columns = ['movie_id', 'predicted_rating']

    return predicted_ratings

# %%
matrix.loc[54]
# Out:
# movieId
# 1        0.125206
# 2        0.081585
# 6       -0.781544
# 10       0.741774
# 11       1.592629
#            ...
# 56367         NaN
# 58559         NaN
# 59315         NaN
# 60069         NaN
# 79132         NaN
# Name: 54, Length: 770, dtype: float64

# %%
user_id = 54
movie=19
top_n = 20
unrated_movies = matrix.loc[user_id][matrix.loc[user_id].isna()].index

# %%
correlation_matrix.loc[matrix.loc[user_id].notna()][movie]
# Out:
# movieId
# 1       0.094306
# 2       0.294449
# 6       0.098752
# 10      0.281455
# 11      0.089616
#           ...
# 3897    0.054327
# 3977    0.207379
# 4002    0.223861
# 4007    0.140418
# 5060    0.063697
# Name: 19, Length: 366, dtype: float64

# %%
user_ratings = matrix.loc[54]

# %%
user_ratings[user_ratings.isnull()].index.tolist()
# Out:
# [19,
#  44,
#  48,
#  62,
#  104,
#  141,
#  145,
#  158,
#  168,
#  172,
#  173,
#  180,
#  198,
#  208,
#  216,
#  231,
#  253,
#  266,
#  293,
#  317,
#  333,
#  353,
#  355,
#  364,
#  420,
#  431,
#  432,
#  434,
#  441,
#  466,
#  471,
#  485,
#  497,
#  500,
#  508,
#  509,
#  520,
#  553,
#  555,
#  588,
#  594,
#  595,
#  596,
#  628,
#  653,
#  673,
#  762,
#  778,
#  784,
#  802,
#  805,
#  852,
#  899,
#  902,
#  903,
#  904,
#  908,
#  910,
#  912,
#  913,
#  914,
#  919,
#  920,
#  923,
#  953,
#  969,
#  1020,
#  1022,
#  1027,
#  1029,
#  1032,
#  1035,
#  1037,
#  1059,
#  1060,
#  1061,
#  1080,
#  1093,
#  1094,
#  1095,
#  1183,
#  1193,
#  1199,
#  1206,
#  1208,
#  1220,
#  1222,
#  1225,
#  1231,
#  1233,
#  1245,
#  1249,
#  1250,
#  1261,
#  1262,
#  1263,
#  1266,
#  1271,
#  1276,
#  1282,
#  1285,
#  1287,
#  1293,
#  1339,
#  1378,
#  1380,
#  1394,
#  1500,
#  1586,
#  1644,
#  1645,
#  1673,
#  1682,
#  1704,
#  1721,
#  1747,
#  1748,
#  1882,
#  1884,
#  1907,
#  1918,
#  1921,
#  1960,
#  1961,
#  1962,
#  2000,
#  2018,
#  2019,
#  2020,
#  2023,
#  2076,
#  2078,
#  2080,
#  2081,
#  2085,
#  2087,
#  2096,
#  2140,
#  2145,
#  2150,
#  2167,
#  2231,
#  2232,
#  2268,
#  2273,
#  2289,
#  2294,
#  2302,
#  2313,
#  2329,
#  2335,
#  2340,
#  2366,
#  2395,
#  2403,
#  2423,
#  2431,
#  2490,
#  2502,
#  2539,
#  2541,
#  2542,
#  2572,
#  2580,
#  2657,
#  2692,
#  2700,
#  2710,
#  2712,
#  2716,
#  2761,
#  2953,
#  2959,
#  2986,
#  3000,
#  3020,
#  3081,
#  3105,
#  3160,
#  3168,
#  3252,
#  3254,
#  3257,
#  3263,
#  3273,
#  3300,
#  3317,
#  3396,
#  3408,
#  3418,
#  3424,
#  3499,
#  3510,
#  3535,
#  3555,
#  3556,
#  3617,
#  3624,
#  3703,
#  3717,
#  3752,
#  3753,
#  3755,
#  3785,
#  3798,
#  3809,
#  3911,
#  3916,
#  3948,
#  3949,
#  3967,
#  3994,
#  3996,
#  4011,
#  4014,
#  4015,
#  4018,
#  4019,
#  4022,
#  4025,
#  4027,
#  4034,
#  4084,
#  4085,
#  4105,
#  4128,
#  4148,
#  4223,
#  4226,
#  4239,
#  4246,
#  4262,
#  4270,
#  4299,
#  4306,
#  4308,
#  4310,
#  4321,
#  4343,
#  4344,
#  4361,
#  4367,
#  4369,
#  4370,
#  4446,
#  4447,
#  4489,
#  4571,
#  4638,
#  4641,
#  4643,
#  4701,
#  4718,
#  4720,
#  4734,
#  4776,
#  4816,
#  4848,
#  4855,
#  4865,
#  4874,
#  4878,
#  4886,
#  4890,
#  4896,
#  4901,
#  4963,
#  4973,
#  4975,
#  4979,
#  4993,
#  4995,
#  5010,
#  5013,
#  5015,
#  5218,
#  5254,
#  5266,
#  5299,
#  5349,
#  5377,
#  5378,
#  5388,
#  5418,
#  5445,
#  5459,
#  5464,
#  5481,
#  5502,
#  5507,
#  5528,
#  5618,
#  5630,
#  5669,
#  5673,
#  5679,
#  5816,
#  5872,
#  5902,
#  5945,
#  5952,
#  5956,
#  5989,
#  5991,
#  5995,
#  6016,
#  6157,
#  6188,
#  6218,
#  6281,
#  6323,
#  6333,
#  6365,
#  6373,
#  6377,
#  6378,
#  6502,
#  6534,
#  6537,
#  6539,
#  6541,
#  6708,
#  6711,
#  6807,
#  6863,
#  6870,
#  6874,
#  6934,
#  6936,
#  6942,
#  6947,
#  6953,
#  6979,
#  7090,
#  7143,
#  7147,
#  7153,
#  7254,
#  7361,
#  7373,
#  7438,
#  7458,
#  8360,
#  8361,
#  8368,
#  8376,
#  8464,
#  8528,
#  8529,
#  8622,
#  8636,
#  8641,
#  8644,
#  8665,
#  8783,
#  8784,
#  8798,
#  8874,
#  8949,
#  8961,
#  8970,
#  8972,
#  8984,
#  30707,
#  30793,
#  30810,
#  30812,
#  32587,
#  33004,
#  33166,
#  33493,
#  33679,
#  33794,
#  34048,
#  34162,
#  34405,
#  35836,
#  37733,
#  40815,
#  40819,
#  41566,
#  41569,
#  44191,
#  44195,
#  45447,
#  45499,
#  45722,
#  46578,
#  48385,
#  48394,
#  48516,
#  48774,
#  48780,
#  49272,
#  50872,
#  51255,
#  51662,
#  54286,
#  55820,
#  56367,
#  58559,
#  59315,
#  60069,
#  79132]
